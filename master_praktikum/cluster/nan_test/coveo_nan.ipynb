# %% [markdown]
# ## Check Coveo Datasets for Nan values in each column

# %%
import pandas as pd

# %% [markdown]
# ---
# ### Without Pageviews

# %%
train_wo_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/without_pageviews/coveo.train.csv", sep="\t")
validation_wo_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/without_pageviews/coveo.validation.csv", sep="\t")
test_wo_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/without_pageviews/coveo.test.csv", sep="\t")

# %%
coveo_full_wo_pageviews = pd.concat([train_wo_pageviews, validation_wo_pageviews, test_wo_pageviews])
coveo_full_wo_pageviews
# Out:
#                                            session_id_hash     event_type  \
# 0        000010504025397b03290c7457e0e7ef7ae93529f21eae...  event_product
# 1        000010504025397b03290c7457e0e7ef7ae93529f21eae...  event_product
# 2        000010504025397b03290c7457e0e7ef7ae93529f21eae...  event_product
# 3        000010504025397b03290c7457e0e7ef7ae93529f21eae...  event_product
# 4        000010504025397b03290c7457e0e7ef7ae93529f21eae...  event_product
# ...                                                    ...            ...
# 1557858  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 1557859  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 1557860  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 1557861  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 1557862  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
#
#         product_action                                   product_sku_hash  \
# ...

# %%
coveo_full_wo_pageviews.isnull().any()
# Out:
# session_id_hash              False
# event_type                   False
# product_action               False
# product_sku_hash             False
# server_timestamp_epoch_ms    False
# hashed_url                   False
# category_hash                 True
# price_bucket                  True
# dtype: bool

# %% [markdown]
# ---
# ### With Pageviews

# %%
train_w_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/with_pageviews/coveo.train.csv", sep="\t")
validation_w_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/with_pageviews/coveo.validation.csv", sep="\t")
test_w_pageviews = pd.read_csv("../coveo_dataset/preprocessed_data/split/with_pageviews/coveo.test.csv", sep="\t")

# %%
coveo_full_w_pageviews = pd.concat([train_w_pageviews, validation_w_pageviews, test_w_pageviews])
coveo_full_w_pageviews
# Out:
#                                            session_id_hash     event_type  \
# 0        00000277639fc5c6f816654b78bf3654ece7fd53a7338f...       pageview
# 1        00000277639fc5c6f816654b78bf3654ece7fd53a7338f...       pageview
# 2        00000277639fc5c6f816654b78bf3654ece7fd53a7338f...       pageview
# 3        00000277639fc5c6f816654b78bf3654ece7fd53a7338f...       pageview
# 4        00000277639fc5c6f816654b78bf3654ece7fd53a7338f...       pageview
# ...                                                    ...            ...
# 3940337  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 3940338  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 3940339  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 3940340  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
# 3940341  ffffec0d60277e1ff859623244115db6f3fcfbeaf56304...  event_product
#
#         product_action                                   product_sku_hash  \
# ...

# %%
coveo_full_w_pageviews.isnull().any()
# Out:
# session_id_hash              False
# event_type                   False
# product_action                True
# product_sku_hash             False
# server_timestamp_epoch_ms    False
# hashed_url                   False
# category_hash                 True
# price_bucket                  True
# dtype: bool
