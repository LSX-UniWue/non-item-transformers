# %% [markdown]
# # H&M: Apply minimum sequence length on split files

# %%
import pandas as pd

# %%
train = pd.read_csv("../hm_dataset/preprocessed_data/split/hm.train.csv", sep="\t")
validation = pd.read_csv("../hm_dataset/preprocessed_data/split/hm.validation.csv", sep="\t")
test = pd.read_csv("../hm_dataset/preprocessed_data/split/hm.test.csv", sep="\t")

# %% [markdown]
# ---
# ### Min sequence length 2

# %%
train.groupby(['customer_id']).size().describe(), validation.groupby(['customer_id']).size().describe(), test.groupby(['customer_id']).size().describe()
# Out:
# (count    1.151249e+06
#  mean     1.932434e+01
#  std      3.069876e+01
#  min      1.000000e+00
#  25%      3.000000e+00
#  50%      9.000000e+00
#  75%      2.300000e+01
#  max      1.287000e+03
#  dtype: float64,
#  count    574270.000000
#  mean          8.298562
#  std          10.252820
#  min           1.000000
#  25%           2.000000
#  50%           5.000000
#  75%          10.000000
#  max         333.000000
#  dtype: float64,
#  count    576162.000000
#  mean          8.239691
#  std          10.197086
#  min           1.000000
#  25%           2.000000
#  50%           5.000000
#  75%          10.000000
#  max         380.000000
#  dtype: float64)

# %%
def apply_min_sequence_length(dataset):
    aggregated = dataset.groupby(['customer_id']).size()
    filtered = aggregated.apply(lambda v: v >= 2)
    filtered = filtered.reset_index()
    filtered.columns = ['customer_id', 'min_sequence_bool']
    ids = filtered[filtered['min_sequence_bool']]['customer_id'].tolist()
    dataset = dataset[dataset['customer_id'].isin(ids)].copy()
    return dataset

# %%
train = apply_min_sequence_length(train)
validation = apply_min_sequence_length(validation)
test = apply_min_sequence_length(test)

# %%
train.groupby(['customer_id']).size().describe(), validation.groupby(['customer_id']).size().describe(), test.groupby(['customer_id']).size().describe()
# Out:
# (count    1.033962e+06
#  mean     2.140295e+01
#  std      3.173179e+01
#  min      2.000000e+00
#  25%      4.000000e+00
#  50%      1.000000e+01
#  75%      2.500000e+01
#  max      1.287000e+03
#  dtype: float64,
#  count    502743.000000
#  mean          9.336953
#  std          10.555527
#  min           2.000000
#  25%           3.000000
#  50%           6.000000
#  75%          11.000000
#  max         333.000000
#  dtype: float64,
#  count    507480.000000
#  mean          9.219506
#  std          10.488072
#  min           2.000000
#  25%           3.000000
#  50%           6.000000
#  75%          11.000000
#  max         380.000000
#  dtype: float64)

# %% [markdown]
# ---

# %%
train.sort_values(['customer_id', 't_dat'], inplace=True)
validation.sort_values(['customer_id', 't_dat'], inplace=True)
test.sort_values(['customer_id', 't_dat'], inplace=True)

# %%
train, validation, test
# Out:
# (                 t_dat                                        customer_id  \
#  0         1.545869e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  1         1.545869e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  2         1.545869e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  3         1.556755e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  4         1.558742e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  ...                ...                                                ...
#  22247119  1.569629e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  22247120  1.570320e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  22247121  1.570320e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  22247122  1.570320e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  22247123  1.579651e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#
#            article_id     price  sales_channel_id   FN  Active  \
#  0          625548001  0.044051                 1  0.0     0.0
#  1          627759010  0.030492                 1  0.0     0.0
#  2          176209023  0.035576                 1  0.0     0.0
#  3          697138006  0.010153                 2  0.0     0.0
#  4          568601006  0.050831                 2  0.0     0.0
#  ...              ...       ...               ...  ...     ...
#  22247119   792782001  0.033881                 1  1.0     1.0
#  22247120   777714001  0.025407                 2  1.0     1.0
#  22247121   799190002  0.012186                 2  1.0     1.0
#  22247122   756720003  0.015237                 2  1.0     1.0
#  22247123   706016002  0.033881                 1  1.0     1.0
#
#           club_member_status fashion_news_frequency   age  ...  \
#  0                    ACTIVE                   NONE  49.0  ...
#  1                    ACTIVE                   NONE  49.0  ...
#  2                    ACTIVE                   NONE  49.0  ...
#  3                    ACTIVE                   NONE  49.0  ...
#  4                    ACTIVE                   NONE  49.0  ...
#  ...                     ...                    ...   ...  ...
#  22247119             ACTIVE              Regularly  21.0  ...
#  22247120             ACTIVE              Regularly  21.0  ...
#  22247121             ACTIVE              Regularly  21.0  ...
#  22247122             ACTIVE              Regularly  21.0  ...
#  22247123             ACTIVE              Regularly  21.0  ...
#
#           graphical_appearance_name colour_group_name  \
#  0                            Solid         Dark Blue
#  1                            Solid         Dark Blue
#  2                            Solid             Black
#  3                 All over pattern        Light Pink
#  4                            Solid             Black
#  ...                            ...               ...
#  22247119                   Melange             Black
#  22247120           Other structure             White
#  22247121                     Solid              Pink
#  22247122                     Solid        Light Pink
#  22247123                     Solid        Light Blue
#
#           perceived_colour_value_name perceived_colour_master_name  \
#  0                               Dark                         Blue
#  1                               Dark                         Blue
#  2                               Dark                        Black
#  3                        Dusty Light                         Pink
#  4                               Dark                        Black
#  ...                              ...                          ...
#  22247119                        Dark                        Black
#  22247120                       Light                        White
#  22247121                Medium Dusty                         Pink
#  22247122                 Dusty Light                         Pink
#  22247123                       Light                         Blue
#
#                   department_name              index_name index_group_name  \
#  0              Young Boy Outdoor  Children Sizes 134-170    Baby/Children
#  1              Kids Girl Outdoor   Children Sizes 92-140    Baby/Children
#  2                  Jacket Street                Menswear         Menswear
#  3         Kids Girl Jersey Fancy   Children Sizes 92-140    Baby/Children
#  4                           Suit              Ladieswear       Ladieswear
#  ...                          ...                     ...              ...
#  22247119                Knitwear                Menswear         Menswear
#  22247120                  Skirts                 Divided          Divided
#  22247121               Campaigns              Ladieswear       Ladieswear
#  22247122           Tops Knitwear                 Divided          Divided
#  22247123                Trousers                 Divided          Divided
#
#                          section_name garment_group_name  \
#  0                     Kids Outerwear            Outdoor
#  1                     Kids Outerwear            Outdoor
#  2                     Mens Outerwear            Outdoor
#  3                          Kids Girl       Jersey Fancy
#  4                   Womens Tailoring            Dressed
#  ...                              ...                ...
#  22247119          Contemporary Smart           Knitwear
#  22247120          Divided Collection             Skirts
#  22247121  Womens Everyday Collection     Special Offers
#  22247122          Divided Collection           Knitwear
#  22247123          Divided Collection           Trousers
#
#                                                  detail_desc
#  0         Padded jacket with a detachable hood, stand-up...
#  1         Padded parka in woven fabric with a soft, brus...
#  2         Short, padded jacket with a jersey-lined hood ...
#  3         Playsuit in cotton jersey with butterfly sleev...
#  4         Fitted jacket in woven fabric with notch lapel...
#  ...                                                     ...
#  22247119  Polo-neck jumper in a soft fine knit with a te...
#  22247120  Short, A-line skirt in a jacquard weave with a...
#  22247121  Oversized top in sweatshirt fabric made from a...
#  22247122  Cardigan in a soft, fine knit with dropped sho...
#  22247123  High-waisted jeans in washed superstretch deni...
#
#  [22129838 rows x 24 columns],
#                  t_dat                                        customer_id  \
#  0        1.584749e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  1        1.584749e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  2        1.584749e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  3        1.584749e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  4        1.584749e+09  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
#  ...               ...                                                ...
#  4765610  1.586045e+09  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...
#  4765611  1.586045e+09  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...
#  4765612  1.586390e+09  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...
#  4765613  1.586390e+09  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...
#  4765614  1.587773e+09  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...
#
#           article_id     price  sales_channel_id   FN  Active  \
#  0         887593002  0.021593                 2  0.0     0.0
#  1         795440001  0.014390                 2  0.0     0.0
#  2         890498002  0.031763                 2  0.0     0.0
#  3         841260003  0.011508                 2  0.0     0.0
#  4         859416011  0.014390                 2  0.0     0.0
#  ...             ...       ...               ...  ...     ...
#  4765610   806241002  0.025407                 2  1.0     1.0
#  4765611   821395003  0.016932                 2  1.0     1.0
#  4765612   840360003  0.013542                 2  1.0     1.0
#  4765613   866755002  0.043203                 2  1.0     1.0
#  4765614   866755002  0.050831                 2  1.0     1.0
#
#          club_member_status fashion_news_frequency   age  ...  \
#  0                   ACTIVE                   NONE  49.0  ...
#  1                   ACTIVE                   NONE  49.0  ...
#  2                   ACTIVE                   NONE  49.0  ...
#  3                   ACTIVE                   NONE  49.0  ...
#  4                   ACTIVE                   NONE  49.0  ...
#  ...                    ...                    ...   ...  ...
#  4765610             ACTIVE              Regularly  18.0  ...
#  4765611             ACTIVE              Regularly  18.0  ...
#  4765612             ACTIVE              Regularly  18.0  ...
#  4765613             ACTIVE              Regularly  18.0  ...
#  4765614             ACTIVE              Regularly  18.0  ...
#
#          graphical_appearance_name colour_group_name  \
#  0                             Dot         Off White
#  1                           Solid             Black
#  2                           Solid    Greenish Khaki
#  3                             Dot       Light Beige
#  4                All over pattern             Black
#  ...                           ...               ...
#  4765610          All over pattern        Light Pink
#  4765611                     Solid             Black
#  4765612                Embroidery             White
#  4765613                     Denim              Blue
#  4765614                     Denim              Blue
#
#          perceived_colour_value_name perceived_colour_master_name  \
#  0                       Dusty Light                        White
#  1                              Dark                        Black
#  2                      Medium Dusty                  Khaki green
#  3                       Dusty Light                        Beige
#  4                              Dark                        Black
#  ...                             ...                          ...
#  4765610                 Dusty Light                         Pink
#  4765611                        Dark                        Black
#  4765612                       Light                        White
#  4765613                Medium Dusty                         Blue
#  4765614                Medium Dusty                         Blue
#
#             department_name        index_name index_group_name  \
#  0                   Jersey        Ladieswear       Ladieswear
#  1             Jersey fancy        Ladieswear       Ladieswear
#  2          Outdoor/Blazers           Divided          Divided
#  3             Jersey fancy        Ladieswear       Ladieswear
#  4             Jersey fancy        Ladieswear       Ladieswear
#  ...                    ...               ...              ...
#  4765610          Nightwear  Lingeries/Tights       Ladieswear
#  4765611     Clean Lingerie  Lingeries/Tights       Ladieswear
#  4765612  Tops Fancy Jersey           Divided          Divided
#  4765613            Dresses           Divided          Divided
#  4765614            Dresses           Divided          Divided
#
#                             section_name garment_group_name  \
#  0                      Womens Tailoring       Jersey Fancy
#  1            Womens Everyday Collection       Jersey Fancy
#  2                    Divided Collection            Outdoor
#  3            Womens Everyday Collection       Jersey Fancy
#  4            Womens Everyday Collection       Jersey Fancy
#  ...                                 ...                ...
#  4765610  Womens Nightwear, Socks & Tigh  Under-, Nightwear
#  4765611                 Womens Lingerie  Under-, Nightwear
#  4765612              Divided Collection       Jersey Fancy
#  4765613              Divided Collection     Dresses Ladies
#  4765614              Divided Collection     Dresses Ladies
#
#                                                 detail_desc
#  0        Top in jersey crêpe. Round neckline with an op...
#  1        Top in softly draping, ribbed jersey with a sh...
#  2        Fitted jacket in washed cotton denim with a co...
#  3        T-shirt in soft jersey with a round neckline w...
#  4        Short-sleeved top in soft jersey made from a c...
#  ...                                                    ...
#  4765610  Pyjamas with a strappy top and shorts in soft ...
#  4765611  Thong briefs in soft jersey made from a cotton...
#  4765612  Straight-cut T-shirt in cotton jersey with a m...
#  4765613  Short, fitted dress in sturdy cotton twill wit...
#  4765614  Short, fitted dress in sturdy cotton twill wit...
#
#  [4694088 rows x 24 columns],
#                  t_dat                                        customer_id  \
#  3        1.597190e+09  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#  4        1.597190e+09  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#  5        1.597190e+09  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#  6        1.597190e+09  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
#  7        1.600042e+09  0000757967448a6cb83efb3ea7a3fb9d418ac7adf2379d...
#  ...               ...                                                ...
#  4747391  1.594858e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  4747392  1.599523e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  4747393  1.599523e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  4747394  1.599523e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#  4747395  1.599610e+09  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...
#
#           article_id     price  sales_channel_id   FN  Active  \
#  3         927530004  0.047441                 2  1.0     1.0
#  4         791587015  0.020322                 2  1.0     1.0
#  5         896152002  0.027102                 2  1.0     1.0
#  6         730683050  0.033881                 2  1.0     1.0
#  7         719530003  0.033881                 2  0.0     0.0
#  ...             ...       ...               ...  ...     ...
#  4747391   795975009  0.011847                 1  1.0     1.0
#  4747392   794819001  0.014322                 2  1.0     1.0
#  4747393   884081001  0.012898                 2  1.0     1.0
#  4747394   689365050  0.010017                 2  1.0     1.0
#  4747395   762846027  0.025407                 1  1.0     1.0
#
#          club_member_status fashion_news_frequency   age  ...  \
#  3                   ACTIVE              Regularly  52.0  ...
#  4                   ACTIVE              Regularly  52.0  ...
#  5                   ACTIVE              Regularly  52.0  ...
#  6                   ACTIVE              Regularly  52.0  ...
#  7                   ACTIVE                   NONE  20.0  ...
#  ...                    ...                    ...   ...  ...
#  4747391             ACTIVE              Regularly  21.0  ...
#  4747392             ACTIVE              Regularly  21.0  ...
#  4747393             ACTIVE              Regularly  21.0  ...
#  4747394             ACTIVE              Regularly  21.0  ...
#  4747395             ACTIVE              Regularly  21.0  ...
#
#          graphical_appearance_name colour_group_name  \
#  3                All over pattern             Black
#  4                           Solid             Green
#  5                           Solid             Black
#  6                            Mesh             Black
#  7                           Solid             Black
#  ...                           ...               ...
#  4747391                     Solid      Light Orange
#  4747392                     Solid             Black
#  4747393                    Stripe             Black
#  4747394                     Solid              Pink
#  4747395                     Solid             Beige
#
#          perceived_colour_value_name perceived_colour_master_name  \
#  3                              Dark                        Black
#  4                      Medium Dusty                         Grey
#  5                              Dark                        Black
#  6                              Dark                        Black
#  7                              Dark                        Black
#  ...                             ...                          ...
#  4747391                 Dusty Light                       Orange
#  4747392                        Dark                        Black
#  4747393                        Dark                        Black
#  4747394                      Medium                         Pink
#  4747395                 Dusty Light                         Mole
#
#                department_name  index_name index_group_name  \
#  3                      Jersey  Ladieswear       Ladieswear
#  4           Ladies Sport Bras       Sport            Sport
#  5                    Knitwear  Ladieswear       Ladieswear
#  6        Ladies Sport Bottoms       Sport            Sport
#  7                    Trousers     Divided          Divided
#  ...                       ...         ...              ...
#  4747391              Knitwear  Ladieswear       Ladieswear
#  4747392              Knitwear  Ladieswear       Ladieswear
#  4747393                Jersey  Ladieswear       Ladieswear
#  4747394            Tops Woven     Divided          Divided
#  4747395                Blouse  Ladieswear       Ladieswear
#
#                         section_name garment_group_name  \
#  3                      Womens Trend       Jersey Fancy
#  4                  Ladies H&M Sport       Jersey Fancy
#  5        Womens Everyday Collection           Knitwear
#  6                  Ladies H&M Sport       Jersey Fancy
#  7                Divided Collection           Trousers
#  ...                             ...                ...
#  4747391               Womens Casual           Knitwear
#  4747392            Womens Tailoring           Knitwear
#  4747393               Womens Casual       Jersey Fancy
#  4747394          Divided Collection            Blouses
#  4747395            Womens Tailoring            Blouses
#
#                                                 detail_desc
#  3        Long dress in mesh with a round neckline, long...
#  4        Straight-cut sports top in fast-drying mesh wi...
#  5        Top in a soft, fine knit containing some wool ...
#  6        Sports tights in fast-drying functional fabric...
#  7        Cargo trousers in stretch twill with a high wa...
#  ...                                                    ...
#  4747391  Fitted jumper in a soft rib knit with a V-neck...
#  4747392  Jumper in a soft fine-knit viscose blend with ...
#  4747393  Short, straight-cut dress in cotton piqué with...
#  4747394  Shirt in a cotton weave with a collar, buttons...
#  4747395  Long-sleeved blouse in woven fabric with a col...
#
#  [4678715 rows x 24 columns])

# %%
train.to_csv(path_or_buf="../hm_dataset/preprocessed_data/split/hm.train.csv", sep="\t", index=False)
validation.to_csv(path_or_buf="../hm_dataset/preprocessed_data/split/hm.validation.csv", sep="\t", index=False)
test.to_csv(path_or_buf="../hm_dataset/preprocessed_data/split/hm.test.csv", sep="\t", index=False)
